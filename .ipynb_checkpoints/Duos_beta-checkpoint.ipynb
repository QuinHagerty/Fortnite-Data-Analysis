# %%
# Things to do for project

# X - Create the SQL database
# O - Query/Pull data from from the Database
# O - Narrow down data in Pandas Dataframe (df is short for a pandas DataFrame)
    # O - Prepare the data for visualization
# O - Visualize the data in MatPlotLib

# %%
# To graph
import matplotlib.pyplot as plot
#import numpy as np
# Reads the SQL/ Manipulate/ Spreadsheet|Dataframe
import pandas as pd
#
# Connect to database, query it
import sqlite3

# %% [markdown]
# All imports, needed for this project, in alphabetical order.

# %% [markdown]
# Requesting data from the Fortnite TRN match traker API

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# <Response [200]> All is well!

# %%
import requests
url = "https://api.fortnitetracker.com/v1/profile/account/b7c3c6c66e08499eade89c43f31ea2be/matches"
headers = {'TRN-Api-Key':'07678e9b-0fe4-447b-907d-8d141073f496'}

r = requests.get(url, headers=headers)
datasnapshot = r.json()
conn = sqlite3.connect('duo_beta_db.db')
JumbData = pd.DataFrame.from_dict(datasnapshot)
JumbData.to_sql("Jumb player data", conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4040f7e5c79a> in <module>()
#       2 conn = sqlite3.connect('duo_beta_db.db')
#       3 JumbData = pd.DataFrame.from_dict(datasnapshot)
# ----> 4 JumbData.to_sql("Jumb player data", conn)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1500                             if_exists=if_exists, index_label=index_label,
#    1501                             dtype=dtype)
# -> 1502         table.create()
#    1503         table.insert(chunksize)
#    1504
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     561         if self.exists():
#     562             if self.if_exists == 'fail':
# --> 563                 raise ValueError("Table '%s' already exists." % self.name)
#     564             elif self.if_exists == 'replace':
#     565                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Jumb player data' already exists.

# %%
import sqlite3
import pandas as pd

# this is the sqlite connection to your sql database
    # you are using sql to query the data from the database
    # and reading it with pandas
conn = sqlite3.connect('duo_beta_db.db')

#SQL QUERY
query = 'select * from "Jumb Player Data"'

#Python to pull the output of SQL Query into a pandas dataframe(saved as 'games')
games = pd.read_sql(query, conn)

# %%
#########
### FRANCE - THe land of data
# sql database(SQLITE)/ (Postgres)/ #Oracle #etc  / MYSQL          #SPAIN-.CSVs
    # in charge of datasource                               # CHINA - Excel
            #  |
##############|V|#################
# Pandasa/Canada
# Pandas - The land of analysis(and spreadsheet)

# citizenry = pd.read_sql(query,conn)

# %%
len(df)
# Out:
# 50

# %%
df
# Out:
#     index                dateCollected         id  kills  matches playlist  \
# 0       0  2018-10-20T18:32:28.1830000  888171863      1        2       p9
# 1       1  2018-10-20T18:32:28.1800000  888171862      4        2      p10
# 2       2  2018-10-20T17:46:19.8430000  887988136     12        2       p2
# 3       3  2018-10-20T17:36:12.3630000  887948653     11        8       p2
# 4       4  2018-10-20T01:50:14.5900000  885504080      0        1       p9
# 5       5  2018-10-20T01:24:33.6300000  885434996     10        3       p9
# 6       6  2018-10-20T00:52:43.7470000  885347553      9        7       p9
# 7       7  2018-10-20T00:52:43.7170000  885347551     43       11      p10
# 8       8  2018-10-18T10:59:08.6030000  879857345     59       29       p2
# 9       9  2018-10-18T10:59:08.5870000  879857343      1        2      p10
# 10     10  2018-10-18T10:59:08.5870000  879857344     12        6       p9
# 11     11  2018-10-16T22:38:31.2100000  875463942     21       14       p9
# 12     12  2018-10-16T22:38:31.2100000  875463943      2        2       p9
# 11   3099     1      0      0      0     2     0     4     1840.6
# 12    369     0      0      0      0     0     0     1     1183.8
# 13     90     0      0      0      0     0     0     0     1180.3
# 14    439     0      0      0      1     0     0     0     1166.7
# 15    369     0      1      0      1     0     0     0     1176.5
# 16    578     0      0      1      0     0     1     0     1171.3
# 17    203     0      0      0      0     0     0     0     1180.2
# 18    765     1      0      0      0     1     0     1     1891.4
# 19   1286     1      0      1      0     0     1     0     1181.2
# 20    535     0      0      0      0     0     0     1     1761.9
# 21    845     1      0      0      0     1     0     1     1745.6
# 22    158     0      0      0      0     0     0     0     1361.6
# 23    260     0      0      0      0     0     0     0     1459.0
# 24    271     0      0      1      0     0     0     0     1646.0
# 25    645     1      0      1      0     0     1     0     1629.1
# 26   1457     1      0      0      0     1     0     2     1548.4
# 27    357     0      0      0      0     0     0     0     1123.6
# 28   2024     0      0      5      0     0     2     0     1488.6
# 29   1245     0      0      0      0     0     0     2     1386.5
# 30    756     0      0      2      0     0     1     0     1204.4
# 31     26     0      0      0      0     0     0     0     1097.8
# 32    171     0      0      0      0     0     0     0     1100.5
# 33     49     0      0      0      0     0     0     0     1099.7
# 34    480     0      0      0      0     0     0     0     1128.1
# 35    698     0      0      1      0     0     0     0     1105.0
# 36     91     0      0      0      0     0     0     0     1134.2
# 37     42     0      0      0      0     0     0     0     1165.1
# 38    525     0      0      0      0     1     0     1     1267.7
# 39    255     0      0      0      0     0     0     0     1181.8
# 40   1166     1      0      0      0     1     0     1     1284.0
# 41     54     0      0      0      0     0     0     0     1089.6
# 42    251     0      0      0      0     0     0     0     1135.6
# 43    627     0      0      0      0     1     0     1     1266.7
# 44    529     0      0      0      0     1     0     1     1190.9
# 45    174     0      0      0      0     0     0     0     1095.4
# 46    511     0      1      0      1     0     0     0     1242.3
# 47    667     0      0      0      0     0     0     0     1094.6
# 48    786     0      0      0      0     0     0     1     1142.5
# 49    882     0      1      0      1     0     0     0     1166.0

# %%
query = "Select sum(kills) kills, sum(matches) matches, ((sum(kills)/1.0)/sum(matches)) kpm, dateCollected date from 'Jumb Player Data' group by 4 order by date "

player2 = pd.read_sql(query, conn) #conn is using sqlite to pass the query through

# %%
#returns the first value from the date column
player['date'][0]
# Out:
# '2018-10-11T19:43:39.6770000'

# %%
#converts a string into a datetime
player['date'] = pd.to_datetime(player['date'])

# %%
#converts a string into a datetime
games['dateCollected'] = pd.to_datetime(games['dateCollected'])

# %%
if 1000 in player2.kills:
    print(True)
else:
    print(False)
#Create the conenction    
# conn = sqlite.connect('database.db', conn)
# Establish a cursor- which lets you parse the SQL line by line
# c = conn.cursor()

# sudo code:
    if id in table:
        c.execute("INSERT line into TABLE")
# Out:
# False

# %%
player - player2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in rsub(left, right)
#     113 def rsub(left, right):
# --> 114     return right - left
#     115
#
# TypeError: ufunc subtract cannot use operands with types dtype('<M8[ns]') and dtype('O')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1029             with np.errstate(all='ignore'):
# -> 1030                 return na_op(lvalues, rvalues)
#    1031         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1014                 mask = notna(x) & notna(y)
# -> 1015                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1016             else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in rsub(left, right)
#     113 def rsub(left, right):
# --> 114     return right - left
#     115
#
# TypeError: ufunc subtract cannot use operands with types dtype('<M8[ns]') and dtype('O')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-c76d7a4e9df5> in <module>()
# ----> 1 player - player2
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1518
#    1519         if isinstance(other, ABCDataFrame):  # Another DataFrame
# -> 1520             return self._combine_frame(other, na_op, fill_value, level)
#    1521         elif isinstance(other, ABCSeries):
#    1522             return _combine_series_frame(self, other, na_op,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _combine_frame(self, other, func, fill_value, level)
#    4737                 # unique columns
#    4738                 result = {col: _arith_op(this[col], other[col])
# -> 4739                           for col in this}
#    4740                 result = self._constructor(result, index=new_index,
#    4741                                            columns=new_columns, copy=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in <dictcomp>(.0)
#    4737                 # unique columns
#    4738                 result = {col: _arith_op(this[col], other[col])
# -> 4739                           for col in this}
#    4740                 result = self._constructor(result, index=new_index,
#    4741                                            columns=new_columns, copy=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _arith_op(left, right)
#    4730             # left._binop(right, func, fill_value=fill_value)
#    4731             left, right = ops.fill_binop(left, right, fill_value)
# -> 4732             return func(left, right)
#    4733
#    4734         if this._is_mixed_type or other._is_mixed_type:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1465
#    1466         try:
# -> 1467             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1468         except TypeError:
#    1469             xrav = x.ravel()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#     207
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#     122     return result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63         _store_test_result(False)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#      67
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1044
#    1045         if is_datetime64_dtype(left) or is_datetime64tz_dtype(left):
# -> 1046             result = dispatch_to_index_op(op, left, right, pd.DatetimeIndex)
#    1047             return construct_result(left, result,
#    1048                                     index=left.index, name=res_name,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1096         left_idx = left_idx._shallow_copy(freq=None)
#    1097     try:
# -> 1098         result = op(left_idx, right)
#    1099     except NullFrequencyError:
#    1100         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1064             rvalues = rvalues.values
#    1065
# -> 1066         result = safe_na_op(lvalues, rvalues)
#    1067         return construct_result(left, result,
#    1068                                 index=left.index, name=res_name, dtype=None)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1032             if is_object_dtype(lvalues):
#    1033                 return libalgos.arrmap_object(lvalues,
# -> 1034                                               lambda x: op(x, rvalues))
#    1035             raise
#    1036
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x)
#    1032             if is_object_dtype(lvalues):
#    1033                 return libalgos.arrmap_object(lvalues,
# -> 1034                                               lambda x: op(x, rvalues))
#    1035             raise
#    1036
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in rsub(left, right)
#     112
#     113 def rsub(left, right):
# --> 114     return right - left
#     115
#     116
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/datetimelike.py in __sub__(self, other)
#     913                 # Array/Index of DateOffset objects
#     914                 result = self._addsub_offset_array(other, operator.sub)
# --> 915             elif is_datetime64_dtype(other) or is_datetime64tz_dtype(other):
#     916                 # DatetimeIndex, ndarray[datetime64]
#     917                 result = self._sub_datelike(other)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_datetime64_dtype(arr_or_dtype)
#     361         return False
#     362     try:
# --> 363         tipo = _get_dtype_type(arr_or_dtype)
#     364     except TypeError:
#     365         return False
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in _get_dtype_type(arr_or_dtype)
#    1870         elif is_interval_dtype(arr_or_dtype):
#    1871             return IntervalDtypeType
# -> 1872         return _get_dtype_type(np.dtype(arr_or_dtype))
#    1873     try:
#    1874         return arr_or_dtype.dtype.type
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_internal.py in _commastring(astr)
#     175                     raise ValueError(
#     176                         'format number %d of "%s" is not recognized' %
# --> 177                         (len(result)+1, astr))
#     178                 startindex = mo.end()
#     179
#
# ValueError: format number 1 of "b'2018-10-11T19:43:39.6770000'" is not recognized

# %%
print(games['dateCollected'][0].date)
# Out:
# <built-in method date of Timestamp object at 0x113630348>
